# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
data = pd.read_csv('data/vincent/accelerometer_5second/__016563_2014-08-08 12-02-19.bin_day1.csv', index_col='timestamp')

# %%
data['acceleration'].plot()
xticks(rotation=45);
